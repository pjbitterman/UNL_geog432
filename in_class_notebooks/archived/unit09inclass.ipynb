# %%
# %matplotlib inline    

import os              # Provides several system utilities
import pandas as pd    # Workhorse of data munging in Python
import geopandas       # The framework for geospatial data tables in Python
import seaborn as sns  # Allows us to efficiently and beautifully plot

# %%
# Read table
print(os.getcwd())
d = pd.read_csv("./unit09data/ne_counties_census.csv", index_col='GEOID')
# Out:
# /Users/pbitterman2/GitRepos/UNL_geog432/in_class_notebooks

# %%
d
# Out:
#        STATEFP10  COUNTYFP10  COUNTYNS10  GEOID10    NAME10       NAMELSAD10  \
# GEOID
# 31021         31          21      835832    31021      Burt      Burt County
# 31047         31          47      835845    31047    Dawson    Dawson County
# 31155         31         155      835899    31155  Saunders  Saunders County
# 31171         31         171      835907    31171    Thomas    Thomas County
# 31003         31           3      835824    31003  Antelope  Antelope County
# ...          ...         ...         ...      ...       ...              ...
# 31089         31          89      835866    31089      Holt      Holt County
# 31141         31         141      835892    31141    Platte    Platte County
# 31059         31          59      835851    31059  Fillmore  Fillmore County
# 31041         31          41      835842    31041    Custer    Custer County
# 31019         31          19      835831    31019   Buffalo   Buffalo County
#
#        LSAD10 CLASSFP10 MTFCC10  CSAFP10  ...  OV150K1749  OV175K1999  \
# GEOID                                     ...
# 31021       6        H1   G4020      NaN  ...         150          74
# 31047       6        H1   G4020      NaN  ...         398         201
# 31155       6        H1   G4020    420.0  ...         539         397
# 31171       6        H1   G4020      NaN  ...           3           0
# 31003       6        H1   G4020      NaN  ...         116          35
# ...       ...       ...     ...      ...  ...         ...         ...
# 31089       6        H1   G4020      NaN  ...          99          66
# 31141       6        H1   G4020      NaN  ...         789         365
# 31059       6        H1   G4020      NaN  ...          69          33
# 31041       6        H1   G4020      NaN  ...         132          88
# 31019       6        H1   G4020      NaN  ...        1321         816
#
#       OV200K2499  OV250K2999  OV300K3999 OV400K4999  OV500K7499  OV750K9999  \
# GEOID
# 31021         93          15          40         19          18           0
# 31047        205          73          27         62          29          26
# 31155        767         450         414        118         134          17
# 31171         17          33           4          3           8           0
# 31003         50          53          49         34          11           0
# ...          ...         ...         ...        ...         ...         ...
# 31089         90          64          97         87          31          15
# 31141        532         383         199        101          96          10
# 31059         71          48          55         42          26           7
# 31041        195          71          35         32          25          26
# 31019       1101         485         289        150          42          54
#
#        OV1MillUp  MedValHous
# GEOID
# 31021          3       83100
# 31047          2       83400
# 31155          7      137500
# 31171          4       71100
# 31003          2       67000
# ...          ...         ...
# 31089         32       82300
# 31141         12      108100
# 31059          7       75100
# 31041         44       71500
# 31019         26      128600
#
# [93 rows x 159 columns]

# %%
d.head()
# Out:
#        STATEFP10  COUNTYFP10  COUNTYNS10  GEOID10    NAME10       NAMELSAD10  \
# GEOID
# 31021         31          21      835832    31021      Burt      Burt County
# 31047         31          47      835845    31047    Dawson    Dawson County
# 31155         31         155      835899    31155  Saunders  Saunders County
# 31171         31         171      835907    31171    Thomas    Thomas County
# 31003         31           3      835824    31003  Antelope  Antelope County
#
#        LSAD10 CLASSFP10 MTFCC10  CSAFP10  ...  OV150K1749  OV175K1999  \
# GEOID                                     ...
# 31021       6        H1   G4020      NaN  ...         150          74
# 31047       6        H1   G4020      NaN  ...         398         201
# 31155       6        H1   G4020    420.0  ...         539         397
# 31171       6        H1   G4020      NaN  ...           3           0
# 31003       6        H1   G4020      NaN  ...         116          35
#
#       OV200K2499  OV250K2999  OV300K3999 OV400K4999  OV500K7499  OV750K9999  \
# GEOID
# 31021         93          15          40         19          18           0
# 31047        205          73          27         62          29          26
# 31155        767         450         414        118         134          17
# 31171         17          33           4          3           8           0
# 31003         50          53          49         34          11           0
#
#        OV1MillUp  MedValHous
# GEOID
# 31021          3       83100
# 31047          2       83400
# 31155          7      137500
# 31171          4       71100
# 31003          2       67000
#
# [5 rows x 159 columns]

# %%
d.tail()
# Out:
#        STATEFP10  COUNTYFP10  COUNTYNS10  GEOID10    NAME10       NAMELSAD10  \
# GEOID
# 31089         31          89      835866    31089      Holt      Holt County
# 31141         31         141      835892    31141    Platte    Platte County
# 31059         31          59      835851    31059  Fillmore  Fillmore County
# 31041         31          41      835842    31041    Custer    Custer County
# 31019         31          19      835831    31019   Buffalo   Buffalo County
#
#        LSAD10 CLASSFP10 MTFCC10  CSAFP10  ...  OV150K1749  OV175K1999  \
# GEOID                                     ...
# 31089       6        H1   G4020      NaN  ...          99          66
# 31141       6        H1   G4020      NaN  ...         789         365
# 31059       6        H1   G4020      NaN  ...          69          33
# 31041       6        H1   G4020      NaN  ...         132          88
# 31019       6        H1   G4020      NaN  ...        1321         816
#
#       OV200K2499  OV250K2999  OV300K3999 OV400K4999  OV500K7499  OV750K9999  \
# GEOID
# 31089         90          64          97         87          31          15
# 31141        532         383         199        101          96          10
# 31059         71          48          55         42          26           7
# 31041        195          71          35         32          25          26
# 31019       1101         485         289        150          42          54
#
#        OV1MillUp  MedValHous
# GEOID
# 31089         32       82300
# 31141         12      108100
# 31059          7       75100
# 31041         44       71500
# 31019         26      128600
#
# [5 rows x 159 columns]

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93 entries, 31021 to 31019
# Columns: 159 entries, STATEFP10 to MedValHous
# dtypes: float64(6), int64(147), object(6)
# memory usage: 116.2+ KB

# %%
d.describe()
# Out:
#        STATEFP10  COUNTYFP10     COUNTYNS10       GEOID10  LSAD10     CSAFP10  \
# count       93.0   93.000000      93.000000     93.000000    93.0    8.000000
# mean        31.0   93.000000  835869.817204  31093.000000     6.0  443.000000
# std          0.0   53.981478      29.438198     53.981478     0.0   42.587725
# min         31.0    1.000000  835823.000000  31001.000000     6.0  420.000000
# 25%         31.0   47.000000  835846.000000  31047.000000     6.0  420.000000
# 50%         31.0   93.000000  835869.000000  31093.000000     6.0  420.000000
# 75%         31.0  139.000000  835892.000000  31139.000000     6.0  443.000000
# max         31.0  185.000000  835991.000000  31185.000000     6.0  512.000000
#
#            CBSAFP10  METDIVFP10  SUMLEVEL    ST  ...    OV150K1749  \
# count     29.000000         0.0      93.0  93.0  ...     93.000000
# mean   31952.413793         NaN      50.0  31.0  ...    523.559140
# std     7554.556645         NaN       0.0   0.0  ...   1910.238572
# min    13100.000000         NaN      50.0  31.0  ...      0.000000
# 25%    25580.000000         NaN      50.0  31.0  ...     38.000000
# 50%    35740.000000         NaN      50.0  31.0  ...    100.000000
# 75%    36540.000000         NaN      50.0  31.0  ...    220.000000
# max    43580.000000         NaN      50.0  31.0  ...  15105.000000
#
#         OV175K1999    OV200K2499   OV250K2999   OV300K3999   OV400K4999  \
# count    93.000000     93.000000    93.000000    93.000000    93.000000
# mean    305.268817    430.731183   235.494624   197.322581    75.935484
# std    1155.029269   1549.465835   882.437923   770.785316   302.145509
# min       0.000000      0.000000     0.000000     0.000000     0.000000
# 25%      12.000000     34.000000    16.000000     8.000000     2.000000
# 50%      36.000000     72.000000    44.000000    29.000000    12.000000
# 75%     109.000000    164.000000    90.000000    77.000000    38.000000
# max    8976.000000  11721.000000  7243.000000  6189.000000  2585.000000
#
#         OV500K7499  OV750K9999   OV1MillUp     MedValHous
# count    93.000000   93.000000   93.000000      93.000000
# mean     62.258065   19.473118   17.440860   83753.763441
# std     274.064968   93.631167   69.129284   25148.608567
# min       0.000000    0.000000    0.000000   41100.000000
# 25%       3.000000    0.000000    0.000000   67000.000000
# 50%       9.000000    0.000000    4.000000   78200.000000
# 75%      31.000000   12.000000   11.000000   95000.000000
# max    2457.000000  861.000000  613.000000  167200.000000
#
# [8 rows x 153 columns]

# %%
d.describe().T
# Out:
#             count           mean           std       min       25%       50%  \
# STATEFP10    93.0      31.000000      0.000000      31.0      31.0      31.0
# COUNTYFP10   93.0      93.000000     53.981478       1.0      47.0      93.0
# COUNTYNS10   93.0  835869.817204     29.438198  835823.0  835846.0  835869.0
# GEOID10      93.0   31093.000000     53.981478   31001.0   31047.0   31093.0
# LSAD10       93.0       6.000000      0.000000       6.0       6.0       6.0
# ...           ...            ...           ...       ...       ...       ...
# OV400K4999   93.0      75.935484    302.145509       0.0       2.0      12.0
# OV500K7499   93.0      62.258065    274.064968       0.0       3.0       9.0
# OV750K9999   93.0      19.473118     93.631167       0.0       0.0       0.0
# OV1MillUp    93.0      17.440860     69.129284       0.0       0.0       4.0
# MedValHous   93.0   83753.763441  25148.608567   41100.0   67000.0   78200.0
#
#                  75%       max
# STATEFP10       31.0      31.0
# COUNTYFP10     139.0     185.0
# COUNTYNS10  835892.0  835991.0
# GEOID10      31139.0   31185.0
# LSAD10           6.0       6.0
# ...              ...       ...
# OV400K4999      38.0    2585.0
# OV500K7499      31.0    2457.0
# OV750K9999      12.0     861.0
# OV1MillUp       11.0     613.0
# MedValHous   95000.0  167200.0
#
# [153 rows x 8 columns]

# %%
maxes = d.max()
maxes

d.columns
for x in d.columns:
    print(x)
# Out:
# STATEFP10
# COUNTYFP10
# COUNTYNS10
# GEOID10
# NAME10
# NAMELSAD10
# LSAD10
# CLASSFP10
# MTFCC10
# CSAFP10
# CBSAFP10
# METDIVFP10
# GEOID10_1
# SUMLEVEL
# ST
# NAME
# COUNTY
# Total
# Male
# MUn5Y
# M5to9Y
# M10to14Y
# M15to17Y
# M18and19Y
# M20Y
# M21Y
# M22to24Y
# M25to29Y
# M30to34Y
# M35to39Y
# M40to44Y
# M45to49Y
# M50to54Y
# M55to59Y
# M60and61Y
# M62to64Y
# M65and66Y
# M67to69Y
# M70to74Y
# M75to79Y
# M80to84Y
# MOv85Y
# Female
# FUn5Y
# F5to9Y
# F10to14Y
# F15to17Y
# F18and19Y
# F20Y
# F21Y
# F22to24Y
# F25to29Y
# F30to34Y
# F35to39Y
# F40to44Y
# F45to49Y
# F50to54Y
# F55to59Y
# F60and61Y
# F62to64Y
# F65and66Y
# F67to69Y
# F70to74Y
# F75to79Y
# F80to84Y
# FOv85Y
# MedianAge
# MedianAgeM
# MedianAgeF
# TotalRace
# White
# BlackorAA
# AmIndAlNat
# Asian
# NHawOPacIs
# Other
# R2orMore
# R2orMInOth
# R2orMNO3R
# TotHispNoH
# NotHisp
# Hisp
# TotalHouse
# FamHouse
# FHMarrCoup
# FHOthFam
# FHMaleHous
# FHFemHous
# NonFamHous
# NFHAlone
# NFHNotAln
# MedHousInc
# MedFamInc
# PerCapInc
# TotalUnits
# Occupied
# Vacant
# GrpQrtPop
# TotPop25Ov
# Male1
# MNoSchool
# MNursto4Gr
# M5and6Gr
# M7and8Gr
# M9Gr
# M10Gr
# M11Gr
# M12GrNoDip
# MHSGdorGED
# MColless1Y
# MColNoDeg
# MAsscDeg
# MBachDeg
# MMastDeg
# MProfDeg
# MDocDeg
# Female1
# FNoSchool
# FNursto4Gr
# F5and6Gr
# F7and8Gr
# F9Gr
# F10Gr
# F11Gr
# F12GrNoDip
# FHSGdorGED
# FColless1Y
# FColNoDeg
# FAsscDeg
# FBachDeg
# FMastDeg
# FProfDeg
# FDocDeg
# OwnOccUnit
# OVLess10K
# OV10K14999
# OV15K19999
# OV20K24999
# OV25K29999
# OV30K34999
# OV35K39999
# OV40K49999
# OV50K5999
# OV60K69999
# OV70K79999
# OV80K89999
# OV90K99999
# OV100K1249
# OV125K1499
# OV150K1749
# OV175K1999
# OV200K2499
# OV250K2999
# OV300K3999
# OV400K4999
# OV500K7499
# OV750K9999
# OV1MillUp
# MedValHous

# %%
d['PerCapInc']

d['PerCapInc'].max
# Out:
# <bound method Series.max of GEOID
# 31021    23302
# 31047    19384
# 31155    26898
# 31171    31499
# 31003    20419
#          ...
# 31089    22498
# 31141    23358
# 31059    21990
# 31041    21685
# 31019    22616
# Name: PerCapInc, Length: 93, dtype: int64>

# %%
d.loc[31059]
# Out:
# STATEFP10           31
# COUNTYFP10          59
# COUNTYNS10      835851
# GEOID10          31059
# NAME10        Fillmore
#                 ...
# OV400K4999          42
# OV500K7499          26
# OV750K9999           7
# OV1MillUp            7
# MedValHous       75100
# Name: 31059, Length: 159, dtype: object

# %%
d.loc[31059]['PerCapInc']
# Out:
# 21990

# %%
m40s = d['M40to44Y'] + d['M45to49Y']
m40s
# Out:
# GEOID
# 31021     490
# 31047    1652
# 31155    1715
# 31171      52
# 31003     459
#          ...
# 31089     806
# 31141    2400
# 31059     398
# 31041     772
# 31019    2825
# Length: 93, dtype: int64

# %%
d['M40s'] = m40s

# %%
d['M40s'] = d['M40to44Y'] + d['M45to49Y']

# %%
del d['M40s']

# %%
lowpops = d.loc[d['Total'] < 2000]
lowpops
# Out:
#        STATEFP10  COUNTYFP10  COUNTYNS10  GEOID10     NAME10  \
# GEOID
# 31171         31         171      835907    31171     Thomas
# 31165         31         165      835904    31165      Sioux
# 31049         31          49      835846    31049      Deuel
# 31007         31           7      835826    31007     Banner
# 31005         31           5      835825    31005     Arthur
# 31057         31          57      835850    31057      Dundy
# 31183         31         183      835913    31183    Wheeler
# 31091         31          91      835867    31091     Hooker
# 31075         31          75      835859    31075      Grant
# 31103         31         103      835873    31103  Keya Paha
# 31113         31         113      835878    31113      Logan
# 31115         31         115      835879    31115       Loup
# 31009         31           9      835827    31009     Blaine
# 31085         31          85      835864    31085      Hayes
# 31117         31         117      835881    31117  McPherson
# 31149         31         149      835896    31149       Rock
#
#              NAMELSAD10  LSAD10 CLASSFP10 MTFCC10  CSAFP10  ...  OV150K1749  \
# GEOID                                                       ...
# 31171     Thomas County       6        H1   G4020      NaN  ...           3
# 31165      Sioux County       6        H1   G4020      NaN  ...          27
# 31049      Deuel County       6        H1   G4020      NaN  ...          36
# 31007     Banner County       6        H1   G4020      NaN  ...          30
# 31005     Arthur County       6        H1   G4020      NaN  ...           7
# 31057      Dundy County       6        H1   G4020      NaN  ...          47
# 31183    Wheeler County       6        H1   G4020      NaN  ...          21
# 31091     Hooker County       6        H1   G4020      NaN  ...          17
# 31075      Grant County       6        H1   G4020      NaN  ...           5
# 31103  Keya Paha County       6        H1   G4020      NaN  ...          17
# 31113      Logan County       6        H1   G4020      NaN  ...          22
# 31115       Loup County       6        H1   G4020      NaN  ...           7
# 31009     Blaine County       6        H1   G4020      NaN  ...           0
# 31085      Hayes County       6        H1   G4020      NaN  ...          41
# 31117  McPherson County       6        H1   G4020      NaN  ...           5
# 31149       Rock County       6        H1   G4020      NaN  ...          20
#
#        OV175K1999 OV200K2499  OV250K2999  OV300K3999 OV400K4999  OV500K7499  \
# GEOID
# 31171           0         17          33           4          3           8
# 31165          25         21          39           6         24          21
# 31049          20         36          13           6          9           0
# 31007           8         13           0           3          0           5
# 31005           3         12           2           7          0           9
# 31057           0         15          14           0          6           9
# 31183           0          4           4           0          0           0
# 31091           6         14           5           8          0           7
# 31075           0          7           7           0          2           3
# 31103           8         20           9           0         15           9
# 31113           5          5          10           0          0           3
# 31115          14         16           0          10          0           0
# 31009           0          5          16           0          0           0
# 31085           0          0          10           6         10           3
# 31117           1         10           0           6          0           0
# 31149           2         11          15           6          0           0
#
#        OV750K9999  OV1MillUp  MedValHous
# GEOID
# 31171           0          4       71100
# 31165          14          8      109300
# 31049           0          0       65600
# 31007           0          4       76900
# 31005           0          0       76100
# 31057           5         21       63400
# 31183          11          0       66100
# 31091           0          0       67800
# 31075           0          2       41100
# 31103           0          8       57500
# 31113           0          6       72200
# 31115           3          0       58900
# 31009           0          6       57600
# 31085           0          7       84500
# 31117           0          0       74400
# 31149           0          0       57300
#
# [16 rows x 159 columns]

# %%
d.query("(Total < 2000) & (Vacant / TotalUnits > .2)")
# Out:
#        STATEFP10  COUNTYFP10  COUNTYNS10  GEOID10     NAME10  \
# GEOID
# 31165         31         165      835904    31165      Sioux
# 31005         31           5      835825    31005     Arthur
# 31057         31          57      835850    31057      Dundy
# 31183         31         183      835913    31183    Wheeler
# 31091         31          91      835867    31091     Hooker
# 31075         31          75      835859    31075      Grant
# 31103         31         103      835873    31103  Keya Paha
# 31113         31         113      835878    31113      Logan
# 31115         31         115      835879    31115       Loup
# 31009         31           9      835827    31009     Blaine
# 31117         31         117      835881    31117  McPherson
# 31149         31         149      835896    31149       Rock
#
#              NAMELSAD10  LSAD10 CLASSFP10 MTFCC10  CSAFP10  ...  OV150K1749  \
# GEOID                                                       ...
# 31165      Sioux County       6        H1   G4020      NaN  ...          27
# 31005     Arthur County       6        H1   G4020      NaN  ...           7
# 31057      Dundy County       6        H1   G4020      NaN  ...          47
# 31183    Wheeler County       6        H1   G4020      NaN  ...          21
# 31091     Hooker County       6        H1   G4020      NaN  ...          17
# 31075      Grant County       6        H1   G4020      NaN  ...           5
# 31103  Keya Paha County       6        H1   G4020      NaN  ...          17
# 31113      Logan County       6        H1   G4020      NaN  ...          22
# 31115       Loup County       6        H1   G4020      NaN  ...           7
# 31009     Blaine County       6        H1   G4020      NaN  ...           0
# 31117  McPherson County       6        H1   G4020      NaN  ...           5
# 31149       Rock County       6        H1   G4020      NaN  ...          20
#
#        OV175K1999 OV200K2499  OV250K2999  OV300K3999 OV400K4999  OV500K7499  \
# GEOID
# 31165          25         21          39           6         24          21
# 31005           3         12           2           7          0           9
# 31057           0         15          14           0          6           9
# 31183           0          4           4           0          0           0
# 31091           6         14           5           8          0           7
# 31075           0          7           7           0          2           3
# 31103           8         20           9           0         15           9
# 31113           5          5          10           0          0           3
# 31115          14         16           0          10          0           0
# 31009           0          5          16           0          0           0
# 31117           1         10           0           6          0           0
# 31149           2         11          15           6          0           0
#
#        OV750K9999  OV1MillUp  MedValHous
# GEOID
# 31165          14          8      109300
# 31005           0          0       76100
# 31057           5         21       63400
# 31183          11          0       66100
# 31091           0          0       67800
# 31075           0          2       41100
# 31103           0          8       57500
# 31113           0          6       72200
# 31115           3          0       58900
# 31009           0          6       57600
# 31117           0          0       74400
# 31149           0          0       57300
#
# [12 rows x 159 columns]

# %%
sns.distplot(d['Total'], kde=False)

# %%
import matplotlib
matplotlib.pyplot.hist(d['Total'])
# Out:
# (array([89.,  1.,  0.,  1.,  0.,  1.,  0.,  0.,  0.,  1.]),
#  array([4.260000e+02, 5.093790e+04, 1.014498e+05, 1.519617e+05,
#         2.024736e+05, 2.529855e+05, 3.034974e+05, 3.540093e+05,
#         4.045212e+05, 4.550331e+05, 5.055450e+05]),
#  <a list of 10 Patch objects>)

# %%
d.hist('Total')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ffc5819f0d0>]],
#       dtype=object)

# %%
d.plot.scatter('Total', 'MedValHous')

# %%
d_age_sorted = d.sort_values('MedianAge', ascending = False)

d_age_sorted.head()
# Out:
#        STATEFP10  COUNTYFP10  COUNTYNS10  GEOID10     NAME10  \
# GEOID
# 31103         31         103      835873    31103  Keya Paha
# 31091         31          91      835867    31091     Hooker
# 31069         31          69      835856    31069     Garden
# 31049         31          49      835846    31049      Deuel
# 31057         31          57      835850    31057      Dundy
#
#              NAMELSAD10  LSAD10 CLASSFP10 MTFCC10  CSAFP10  ...  OV150K1749  \
# GEOID                                                       ...
# 31103  Keya Paha County       6        H1   G4020      NaN  ...          17
# 31091     Hooker County       6        H1   G4020      NaN  ...          17
# 31069     Garden County       6        H1   G4020      NaN  ...          37
# 31049      Deuel County       6        H1   G4020      NaN  ...          36
# 31057      Dundy County       6        H1   G4020      NaN  ...          47
#
#        OV175K1999 OV200K2499  OV250K2999  OV300K3999 OV400K4999  OV500K7499  \
# GEOID
# 31103           8         20           9           0         15           9
# 31091           6         14           5           8          0           7
# 31069           0          0          14          13          0          15
# 31049          20         36          13           6          9           0
# 31057           0         15          14           0          6           9
#
#        OV750K9999  OV1MillUp  MedValHous
# GEOID
# 31103           0          8       57500
# 31091           0          0       67800
# 31069           0         11       58700
# 31049           0          0       65600
# 31057           5         21       63400
#
# [5 rows x 159 columns]

# %%
import numpy as np
d['pop_cat'] = np.where(d['Total'] > 20000, "Big", "Small")

d_smaller = d[['MedianAge', 'MedFamInc', 'Total', 'pop_cat']]

# %%
d_smaller = d[['MedianAge', 'MedFamInc', 'Total', 'pop_cat']]

d_smaller
d_pop_grouped = d_smaller.groupby('pop_cat')
d_pop_grouped

d_pop_grouped.sum()
# Out:
#          MedianAge  MedFamInc    Total
# pop_cat
# Big          631.5    1045322  1379814
# Small       3363.5    3941340   419311

# %%
d_pop_grouped.sum()
# Out:
#          STATEFP10  COUNTYFP10  COUNTYNS10  GEOID10  LSAD10  CSAFP10  \
# pop_cat
# False         2356        7138    63526172  2363138     456    512.0
# True           527        1511    14209721   528511     102   3032.0
#
#          CBSAFP10  METDIVFP10  SUMLEVEL    ST  ...  OV150K1749  OV175K1999  \
# pop_cat                                        ...
# False    392600.0         0.0      3800  2356  ...        7655        3458
# True     534020.0         0.0       850   527  ...       41036       24932
#
#          OV200K2499  OV250K2999  OV300K3999  OV400K4999  OV500K7499  \
# pop_cat
# False          5980        3494        2466        1151         897
# True          34078       18407       15885        5911        4893
#
#          OV750K9999  OV1MillUp  MedValHous
# pop_cat
# False           277        382     5761800
# True           1534       1240     2027300
#
# [2 rows x 153 columns]

# %%
# read some shapefiles
counties = geopandas.read_file("./unit09data/County_Boundaries-_Census.shp")
counties
# Out:
#     OBJECTID STATEFP10 COUNTYFP10 COUNTYNS10 GEOID10    NAME10  \
# 0          1        31        021   00835832   31021      Burt
# 1          2        31        047   00835845   31047    Dawson
# 2          3        31        155   00835899   31155  Saunders
# 3          4        31        171   00835907   31171    Thomas
# 4          5        31        003   00835824   31003  Antelope
# ..       ...       ...        ...        ...     ...       ...
# 88        89        31        089   00835866   31089      Holt
# 89        90        31        141   00835892   31141    Platte
# 90        91        31        059   00835851   31059  Fillmore
# 91        92        31        041   00835842   31041    Custer
# 92        93        31        019   00835831   31019   Buffalo
#
#          NAMELSAD10 LSAD10 CLASSFP10 MTFCC10  ... OV400K4999 OV500K7499  \
# 0       Burt County     06        H1   G4020  ...         19         18
# 1     Dawson County     06        H1   G4020  ...         62         29
# 2   Saunders County     06        H1   G4020  ...        118        134
# 3     Thomas County     06        H1   G4020  ...          3          8
# 4   Antelope County     06        H1   G4020  ...         34         11
# ..              ...    ...       ...     ...  ...        ...        ...
# 88      Holt County     06        H1   G4020  ...         87         31
# 89    Platte County     06        H1   G4020  ...        101         96
# 90  Fillmore County     06        H1   G4020  ...         42         26
# 91    Custer County     06        H1   G4020  ...         32         25
# 92   Buffalo County     06        H1   G4020  ...        150         42
#
#    OV750K9999 OV1MillUp  MedValHous                                GlobalID  \
# 0           0         3       83100  {4EDC3A23-F380-4AE5-927A-5F1B1688153B}
# 1          26         2       83400  {BD7D0544-A999-4E49-840D-A2BF4E50E1CC}
# 2          17         7      137500  {C89D4E1F-7D16-46B0-95D9-39F654D22F56}
# 3           0         4       71100  {0B2919CE-9E2D-4DFD-85D2-235599DB06CE}
# 4           0         2       67000  {C8004943-C719-4A48-8936-A313AE050BB9}
# ..        ...       ...         ...                                     ...
# 88         15        32       82300  {D0A47FAA-3FA6-4430-978F-7DB48C717302}
# 89         10        12      108100  {63599362-77F2-4C75-918E-013A24C03524}
# 90          7         7       75100  {6D82F2B2-CC54-4714-AD18-A800B507AB92}
# 91         26        44       71500  {90545D52-BA67-4E4B-B0F6-354240FBD3E6}
# 92         54        26      128600  {A8EFE11D-8FFE-4D84-AB97-6D2C4858CD46}
#
#    GDB_GEOMAT    Shape__Are    Shape__Len  \
# 0        None  1.384835e+10  5.536976e+05
# 1        None  2.840421e+10  7.145876e+05
# 2        None  2.116860e+10  6.227946e+05
# 3        None  1.988304e+10  5.674366e+05
# 4        None  2.392317e+10  6.332230e+05
# ..        ...           ...           ...
# 88       None  6.736909e+10  1.057122e+06
# 89       None  1.907224e+10  6.065896e+05
# 90       None  1.606628e+10  5.072658e+05
# 91       None  7.176532e+10  1.080026e+06
# 92       None  2.717748e+10  6.709779e+05
#
#                                              geometry
# 0   POLYGON ((-96.27313 42.04717, -96.27278 42.046...
# 1   POLYGON ((-99.42599 41.04648, -99.42592 41.035...
# 2   POLYGON ((-96.47073 41.39325, -96.47070 41.393...
# 3   POLYGON ((-100.26763 42.08615, -100.26787 42.0...
# 4   POLYGON ((-97.83454 42.08976, -97.83445 42.089...
# ..                                                ...
# 88  POLYGON ((-98.30516 42.76121, -98.30516 42.760...
# 89  POLYGON ((-97.25243 41.74309, -97.25244 41.742...
# 90  POLYGON ((-97.36841 40.69863, -97.36840 40.698...
# 91  POLYGON ((-99.22184 41.74080, -99.21278 41.740...
# 92  POLYGON ((-98.74853 41.04665, -98.74495 41.046...
#
# [93 rows x 174 columns]

# %%
counties.plot()

# %%
counties.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Columns: 174 entries, OBJECTID to geometry
# dtypes: float64(6), geometry(1), int64(144), object(23)
# memory usage: 126.5+ KB

# %%
for x in counties.columns:
    print(x)
# Out:
# OBJECTID
# STATEFP10
# COUNTYFP10
# COUNTYNS10
# GEOID10
# NAME10
# NAMELSAD10
# LSAD10
# CLASSFP10
# MTFCC10
# CSAFP10
# CBSAFP10
# METDIVFP10
# FUNCSTAT10
# ALAND10
# AWATER10
# INTPTLAT10
# INTPTLON10
# Shape_Leng
# GEOID10_1
# GEOID
# SUMLEVEL
# ST
# NAME
# COUNTY
# TRACT
# BLKGRP
# Total
# Male
# MUn5Y
# M5to9Y
# M10to14Y
# M15to17Y
# M18and19Y
# M20Y
# M21Y
# M22to24Y
# M25to29Y
# M30to34Y
# M35to39Y
# M40to44Y
# M45to49Y
# M50to54Y
# M55to59Y
# M60and61Y
# M62to64Y
# M65and66Y
# M67to69Y
# M70to74Y
# M75to79Y
# M80to84Y
# MOv85Y
# Female
# FUn5Y
# F5to9Y
# F10to14Y
# F15to17Y
# F18and19Y
# F20Y
# F21Y
# F22to24Y
# F25to29Y
# F30to34Y
# F35to39Y
# F40to44Y
# F45to49Y
# F50to54Y
# F55to59Y
# F60and61Y
# F62to64Y
# F65and66Y
# F67to69Y
# F70to74Y
# F75to79Y
# F80to84Y
# FOv85Y
# MedianAge
# MedianAgeM
# MedianAgeF
# TotalRace
# White
# BlackorAA
# AmIndAlNat
# Asian
# NHawOPacIs
# Other
# R2orMore
# R2orMInOth
# R2orMNO3R
# TotHispNoH
# NotHisp
# Hisp
# TotalHouse
# FamHouse
# FHMarrCoup
# FHOthFam
# FHMaleHous
# FHFemHous
# NonFamHous
# NFHAlone
# NFHNotAln
# MedHousInc
# MedFamInc
# PerCapInc
# TotalUnits
# Occupied
# Vacant
# GrpQrtPop
# TotPop25Ov
# Male1
# MNoSchool
# MNursto4Gr
# M5and6Gr
# M7and8Gr
# M9Gr
# M10Gr
# M11Gr
# M12GrNoDip
# MHSGdorGED
# MColless1Y
# MColNoDeg
# MAsscDeg
# MBachDeg
# MMastDeg
# MProfDeg
# MDocDeg
# Female1
# FNoSchool
# FNursto4Gr
# F5and6Gr
# F7and8Gr
# F9Gr
# F10Gr
# F11Gr
# F12GrNoDip
# FHSGdorGED
# FColless1Y
# FColNoDeg
# FAsscDeg
# FBachDeg
# FMastDeg
# FProfDeg
# FDocDeg
# OwnOccUnit
# OVLess10K
# OV10K14999
# OV15K19999
# OV20K24999
# OV25K29999
# OV30K34999
# OV35K39999
# OV40K49999
# OV50K5999
# OV60K69999
# OV70K79999
# OV80K89999
# OV90K99999
# OV100K1249
# OV125K1499
# OV150K1749
# OV175K1999
# OV200K2499
# OV250K2999
# OV300K3999
# OV400K4999
# OV500K7499
# OV750K9999
# OV1MillUp
# MedValHous
# GlobalID
# GDB_GEOMAT
# Shape__Are
# Shape__Len
# geometry

# %%
counties.loc[0]
# Out:
# OBJECTID                                                      1
# STATEFP10                                                    31
# COUNTYFP10                                                  021
# COUNTYNS10                                             00835832
# GEOID10                                                   31021
#                                     ...
# GlobalID                 {4EDC3A23-F380-4AE5-927A-5F1B1688153B}
# GDB_GEOMAT                                                 None
# Shape__Are                                          1.38483e+10
# Shape__Len                                               553698
# geometry      POLYGON ((-96.27312820455626 42.04716535152583...
# Name: 0, Length: 174, dtype: object

# %%
counties.loc[0, "geometry"]

# %%
# Out:
# OBJECTID                                                      1
# STATEFP10                                                    31
# COUNTYFP10                                                  021
# COUNTYNS10                                             00835832
# GEOID10                                                   31021
#                                     ...
# GlobalID                 {4EDC3A23-F380-4AE5-927A-5F1B1688153B}
# GDB_GEOMAT                                                 None
# Shape__Are                                          1.38483e+10
# Shape__Len                                               553698
# geometry      POLYGON ((-96.27312820455626 42.04716535152583...
# Name: 0, Length: 174, dtype: object
